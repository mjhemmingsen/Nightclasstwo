# %% [markdown]
# Create a checking account class that has the following attributes
#
# balance --> initialize to 0
# transactions --> initialize to an empyt list
#
#
# FUNCTIONS
#
# deposit
# withdrawl
# balance
#
#
#
# Create a savings account class that has the following attributes
#
#
# balance --> initialize to 0
# transactions --> initialize to an empty list
# intrestRate --> define in constuctor
#
# FUNCTIONS
#
# deposit
# withdrawl
# balance
# applyIntrest
#
#
# Create a BankAccount class with the following attributes
#
# idnum --> defined in constuctor
# checkingAccount --> initialize to a new checking account
# savingsAccount --> initialize to a new savings account
# totalDeposits --> 0
# totalWithdraw --> 0
# totalBalance --> checkingBal + savingsBal
#
# FUNCTIONS
#
# withdraw --> (self, amount, account)
# deposit --> (self, amount, account)
# transfer --> transfer(self, to, from, amount)
#
# getters for all attributes
#
# a __str__ repr of the BankAccount
#
#
#
# Now create a Bank class with the following attributes
#
# name --> defined in constructor aka name of your bank
#
# memberSize --> initialize to 0
#
# members --> initialize to an empty list
#
# totalWorth --> initalize to 0
#
#
# FUNCTIONS
#
# create account -->
#  1) This will create a new bank account and set the id to between 1000 and 9999 if that number already exist as a member id keep asking until we get a unique number
#
#  2) Now add this bankaccount to the members list
#
#  3) increment memberSize
#
#
# get members -->
#
#  1) print each member id number and their total balance
#
#
# get total worth -->
#
#   1) loop through the members and sum their total balances
#
#   2) return this number
#
#
# sign in -->
#
#     1) ask for account number
#
#     2) display the following menu until user quits
#
#         "How may I help you choose one of the following"
#
#         1) Withdraw --> bring up sub menu
#
#             a) 'withdraw from checking or savings'
#
#         2) depoist --> bring up sub menu
#
#             b) 'deposite to checking or savings
#
#         3) check balance --> print balance
#
#
#         4) transfer to savings --> bring up sub menu
#
#             a) "How much would you like to transfer
#
#         5) transfer to checking
#
#             a) "How much would you like to transfer"
#
#         6) quit --> exit loop go back to main bank menu
#
#
#
#
#
# Now the last part is create a seperate file and a main function inside main create a new Bank (You can give it whatever name you want) now prompt the user with the following menu
#
#
# "Welcome to {name of bank} bank how may I help you"
#
# 1) Open a new account --> open new account
#
# 2) Sign into a account --> use sign in function
#
# 3) See a list of members --> print members
#
# 4) See our total worth --> return total worth
#
# 5) Leave --> Exits with message
#
#     "Thank you have a nice day"
